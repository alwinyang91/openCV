# %% [markdown]
# # 1. Import Dependencies

# %%
# Import opencv
import cv2
# Import operating sys
import os
# Import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# # 2. Setting up a Captures

# %%
# Setup capture to video 
# The VideoCapture class also allow you to connect to different USB video devices like webcams and microscopes for computer vision
cap = cv2.VideoCapture(os.path.join('data','videos','beach.mp4'))
cap
# Out:
# < cv2.VideoCapture 0x1171563b0>

# %%
# Grab a frame
ret, frame = cap.read()
ret # see if success
# Out:
# True

# %%
frame
# Out:
# array([[[117, 113, 144],
#         [117, 113, 144],
#         [117, 113, 144],
#         ...,
#         [137, 140, 198],
#         [137, 140, 198],
#         [137, 140, 198]],
#
#        [[117, 113, 144],
#         [117, 113, 144],
#         [117, 113, 144],
#         ...,
#         [137, 140, 198],
#         [137, 140, 198],
#         [137, 140, 198]],
#
#        [[117, 113, 144],
#         [117, 113, 144],
#         [117, 113, 144],
#         ...,
#         [137, 140, 198],
#         [137, 140, 198],
#         [137, 140, 198]],
#
#        ...,
#
#        [[ 27,  24,  33],
#         [ 27,  24,  33],
#         [ 27,  24,  33],
#         ...,
#         [ 30,  27,  47],
#         [ 30,  27,  47],
#         [ 30,  27,  47]],
#
#        [[ 30,  24,  33],
#         [ 30,  24,  33],
#         [ 30,  24,  33],
#         ...,
#         [ 30,  28,  46],
#         [ 30,  28,  46],
#         [ 30,  28,  46]],
#
#        [[ 30,  24,  33],
#         [ 30,  24,  33],
#         [ 30,  24,  33],
# ...

# %%
frame.shape
# Out:
# (720, 1280, 3)

# %%
# Render frame 
plt.imshow(frame)
plt.show()

# %%
# Render frame 
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Release capture
cap.release()

# %%
cap.read()
# Out:
# (False, None)

# %% [markdown]
# # 3. Capture Properties

# %%
cap = cv2.VideoCapture(os.path.join('data','videos','beach.mp4'))

# %%
# Height
cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
# Out:
# 720.0

# %%
# Width
cap.get(cv2.CAP_PROP_FRAME_WIDTH)
# Out:
# 1280.0

# %%
# Get number of frames
cap.get(cv2.CAP_PROP_FRAME_COUNT)
# Out:
# 481.0

# %%
# Frames per second
cap.get(cv2.CAP_PROP_FPS)
# Out:
# 24.0

# %%
# The time of the video
cap.get(cv2.CAP_PROP_FRAME_COUNT)/cap.get(cv2.CAP_PROP_FPS)
# Out:
# 20.041666666666668

# %% [markdown]
# # 4. Working with Video Captures

# %%
# Establish capture
cap = cv2.VideoCapture(os.path.join('data','videos','coders.mp4'))
# Loop through each frame
for frame_idx in range(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))):
    
    # Read frame 
    ret, frame = cap.read()
    
    # Gray transform
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Show image
    cv2.imshow('Video Player', gray)
    
    # Breaking out of the loop
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Close down everything
cap.release()
cv2.destroyAllWindows()
# Out:
# OpenCV: Couldn't read video stream from file "data/videos/coders.mp4"

# %% [markdown]
# # 5. Writing out Videos

# %% [markdown]
# ## 5.1 show the video

# %%
# Establish capture
cap = cv2.VideoCapture(os.path.join('data','videos','beach.mp4'))

                                                                                        
# Loop through each frame
for frame_idx in range(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))):
    
    # Read frame 
    ret, frame = cap.read()
    
    # Gray transform
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Show image
    cv2.imshow('Video Player', gray)
    
    
    # Breaking out of the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Close down everything
cap.release()
cv2.destroyAllWindows()

# %%
# Close down everything
cv2.waitKey(1)
cv2.destroyAllWindows()

# %% [markdown]
# ## 5.2 save new video

# %%
# Establish capture
cap = cv2.VideoCapture(os.path.join('data','videos','beach.mp4'))

# new video's properties
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
fps = cap.get(cv2.CAP_PROP_FPS)

# Video Writer 
video_writer = cv2.VideoWriter(os.path.join('data','videos_output','beach-gray.avi'), cv2.VideoWriter_fourcc('P','I','M','1'), fps, (width, height), isColor=False) 
                                                                                        
# Loop through each frame
for frame_idx in range(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))):
    
    # Read frame 
    ret, frame = cap.read()
    
    # Gray transform
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    # Show image
    cv2.imshow('Video Player', gray)
    
    # Write out frame 
    video_writer.write(gray)
    
    # Breaking out of the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Close down everything
cap.release()
cv2.destroyAllWindows()
# Release video writer
video_writer.release()

# %%
# Close down everything
cv2.waitKey(1)
cv2.destroyAllWindows()
